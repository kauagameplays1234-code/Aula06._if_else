# %% [markdown]
# <a href="https://colab.research.google.com/github/kauagameplays1234-code/Aula06._if_else/blob/main/Aula06_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("digite sua idade: "))

if idade >= 18:
  print("você é maior de idade!")

else:
  print("você é menor de idade")
# Out:
# digite sua idade: 18
# você foi aceito

# %%
idade = int(input("digite sua idade: "))

if idade < 16:
  print("você é menor de idade")
elif idade >= 16 and idade < 18:
  print("seu voto é opcional")
elif idade >= 18:
  print("seu voto é obrigatório")
else:
  print("digite um valor compativel")

# %%
#Atividade 01
pagamento = input("digite sua forma de pagamento: ")

if pagamento == "cartão":
  print("processando pagamento em cartão")
elif pagamento == "boleto":
  print("gerando boleto bancário")
else:
  print("pagamento não reconhecido")

# %%
#Atividade 02

idade = int(input("digite a sua idade: "))

if idade <= 12:
  print("você é criança")
elif idade >= 13 and idade <= 17:
  print("você é adolescente")
elif idade >= 18 and idade <= 59:
  print("você é adulto")
elif idade >= 60:
  print("você é idoso")

# %%
#Atividade 03

entrega = input("selecione o tipo de entrega: (padrão/expresso)")

if entrega == "padrão":
  print("essa entrega custa R$ 10,00 reais")
elif entrega == "expresso":
  print("essa entrega custa R$ 20,00 reais")
else:
  print("essa forma de entrega não está disponível")
# Out:
# selecione o tipo de entrega: (padrão/expresso)padrão
# essa entrega custa R$ 10,00 reais

# %%
#Atividade 04

numero = float(input("digite um número: "))

if numero > 0:
  print("esse número é positivo")
elif numero == 0:
  print("esse número é neutro")
else:
  print("esse número é negativo")
# Out:
# digite um número: -2
# esse número é negativo

# %%
#Atividade 05

numero = int(input("digite um numero: "))

if numero % 2 == 0:
  print("número par")
else:
  print("número impar")
# Out:
# digite um numero: 63
# número impar

# %%
#Atividade 06

nota = float(input("digite sua nota: "))

if nota >= 7:
  print("você foi aprovado")
elif nota >= 5:
  print("você está de recuperação")
else:
  print("você foi reprovado")
# Out:
# digite sua nota: 4.2
# você foi reprovado

# %%
#Atividade 07

login = input("digite seu login: ")
senha = input("digite sua senha: ")

if login == "admin" and senha == "1234":
  print("login realizado")
else:
  print("login ou senha inválido")
# Out:
# digite seu login: adimin
# digite sua senha: 321
# login ou senha inválido
